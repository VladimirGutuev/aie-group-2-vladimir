# %%
import numpy as np # импорт библиотеки np

# %% [markdown]
# # Создание массивов

# %%
first_array = np.array([3, 5, 6, 6]) # обычный массив
zeros_array = np.zeros((2,3)) # Массив нулей 2 на 3
ones_array = np.ones((3, 2)) # Массив единиц 3 на 2
arange_array = np.arange(0, 11, 2) # Массив arange

# %% [markdown]
# # Проверяем размерность и тип данных

# %% [markdown]
# #

# %%
print(f' Размерность:{arange_array.shape}, Тип данных в массиве: {arange_array.dtype}')
# Out:
#  Размерность:(6,), Тип данных в массиве: int64

# %% [markdown]
# # Индексирование и срезы

# %%
print(f'Извлечение элемента по индексу: {first_array[1]}, Срез (первая строчка:{ones_array[0, :]}')
# Out:
# Извлечение элемента по индексу: 5, Срез (первая строчка:[1. 1.]

# %% [markdown]
# # Примеры векторных операций и базовых статистик

# %%
second_array = np.array([1,10,9,12])
print(first_array + second_array) # поэлементное сложение
print(first_array * second_array) # поэлементное умножение
mean_value_of_array = first_array.mean() # вычисление среднего арифметического
mean_value_of_array
# Out:
# [ 4 15 15 18]
# [ 3 50 54 72]
# np.float64(5.0)
